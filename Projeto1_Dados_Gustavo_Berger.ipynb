# %% [markdown]
# # Projeto 1 - Ciência dos Dados
# ### Gustavo Berger 2 Eng A
#
#
#
# O quão verdadeira é a suposta democratização de tecnologia após a revolução informacional do início do século XXI?

# %% [markdown]
# ### Introdução - O motivo da escolha do tema
#
# Após a revolução técno-científica-informacional do fim do século XX , foi muito disseminada a ideia de que a tecnologia se democratizou ao redor do mundo, garantindo a maioria dos países o acesso à informação e aos novos instrumentos de comunicação. Com esse projeto tenho a intenção de verificar se isso realmente ocorreu.

# %% [markdown]
# ### Primeiros Passos do código
#
# Para o início do código foi necessário baixar os dados do site gapminder.org como uma planilha excel e importa-los para o jupyter, assim como a biblioteca pandas.
#
# Nessas primeiras células também ocorreu a manipulação das tabelas para que só fosse disposto o ano de 2015, com os títulos das colunas desejadas.

# %%
import pandas as pd

internet = pd.read_excel('internet_users.xlsx')
i= internet.set_index('geo')
hdi= pd.read_excel('hdi_human_development_index.xlsx')
h= hdi.set_index('geo')
celular= pd.read_excel('cell_phones_per_100_people.xlsx')
c= celular.set_index('geo')

# %%
internet_final = i.iloc[:,55:56]
hdi_final= h.iloc[:,25:26]
celular_final= c.iloc[:,55:56]

# %%
hdi_internet = hdi_final.join(internet_final, how='inner', rsuffix='_internet', lsuffix='_hdi')
hdi_internet["% que usa internet"]= hdi_internet.pop("2015_internet")
hdi_internet["IDH"]= hdi_internet.pop("2015_hdi")

# %%
Dados= hdi_internet.join(celular_final, how='inner')
Dados["Celulares para cada 100 pessoas"]= Dados.pop(2015)
Dados
# Out:
#                                 % que usa internet    IDH  \
# geo
# Afghanistan                                   5.90  0.476
# Albania                                      57.20  0.761
# Algeria                                      22.50  0.741
# Andorra                                      94.00  0.850
# Angola                                        8.90  0.527
# Antigua and Barbuda                          63.40  0.782
# Argentina                                    59.90  0.825
# Armenia                                      41.90  0.739
# Australia                                    83.50  0.936
# Austria                                      80.60  0.892
# Azerbaijan                                   73.00  0.752
# Bahamas                                      72.00  0.789
# Bahrain                                      90.00  0.820
# Bangladesh                                    6.63  0.570
# Barbados                                     71.80  0.793
# Belarus                                      54.20  0.796
# Belgium                                      82.20  0.890
# Belize                                       33.60  0.705
# Benin                                         4.90  0.475
# Bhutan                                       22.40  0.596
# Bolivia                                      37.00  0.666
# Bosnia and Herzegovina                       48.50  0.742
# Botswana                                     30.00  0.697
# Brazil                                       51.00  0.747
# Brunei                                       64.50  0.863
# Bulgaria                                     53.10  0.787
# Burkina Faso                                  9.10  0.398
# Burundi                                       1.26  0.404
# Cambodia                                      6.80  0.553
# Cameroon                                     10.00  0.507
# ...                                            ...    ...
# St. Vincent and the Grenadines               43.50  0.720
# Sudan                                        22.70  0.485
# Suriname                                     37.40  0.722
# Swaziland                                    24.70  0.541
# Sweden                                       94.80  0.906
# Switzerland                                  86.30  0.936
# Syria                                        26.20  0.575
# Tajikistan                                   16.00  0.622
# Tanzania                                      4.40  0.512
# Thailand                                     28.90  0.737
# Timor-Leste                                  11.00  0.612
# Togo                                          4.50  0.475
# Tonga                                        32.80  0.716
# Trinidad and Tobago                          63.80  0.778
# Tunisia                                      43.80  0.722
# Turkey                                       46.30  0.759
# Turkmenistan                                  9.60  0.683
# Uganda                                       15.50  0.483
# Ukraine                                      41.00  0.746
# United Arab Emirates                         88.00  0.832
# United Kingdom                               89.80  0.904
# United States                                71.40  0.916
# Uruguay                                      57.70  0.791
# Uzbekistan                                   26.80  0.690
# Vanuatu                                      11.30  0.596
# Venezuela                                    54.90  0.771
# Vietnam                                      38.50  0.675
# Yemen                                        20.00  0.500
# Zambia                                       15.40  0.570
# Zimbabwe                                     15.50  0.498
#
#                                 Celulares para cada 100 pessoas
# geo
# Afghanistan                                                58.4
# Albania                                                   116.0
# Algeria                                                   108.0
# Andorra                                                    91.4
# Angola                                                     49.8
# Antigua and Barbuda                                       176.0
# Argentina                                                 142.0
# Armenia                                                   119.0
# Australia                                                 108.0
# Austria                                                   155.0
# Azerbaijan                                                111.0
# Bahamas                                                    80.4
# Bahrain                                                   184.0
# Bangladesh                                                 81.5
# Barbados                                                  118.0
# Belarus                                                   121.0
# Belgium                                                   113.0
# Belize                                                     59.0
# Benin                                                      88.1
# Bhutan                                                     85.8
# Bolivia                                                    94.8
# Bosnia and Herzegovina                                     97.4
# Botswana                                                  157.0
# Brazil                                                    125.0
# Brunei                                                    111.0
# Bulgaria                                                  128.0
# Burkina Faso                                               79.8
# Burundi                                                    49.0
# Cambodia                                                  134.0
# Cameroon                                                   79.5
# ...                                                         ...
# St. Vincent and the Grenadines                            104.0
# Sudan                                                      72.3
# Suriname                                                  136.0
# Swaziland                                                  71.3
# Sweden                                                    129.0
# Switzerland                                               135.0
# Syria                                                      76.4
# Tajikistan                                                 99.3
# Tanzania                                                   73.6
# Thailand                                                  150.0
# Timor-Leste                                               111.0
# Togo                                                       65.5
# Tonga                                                      69.1
# Trinidad and Tobago                                       156.0
# Tunisia                                                   129.0
# Turkey                                                     94.1
# Turkmenistan                                              141.0
# Uganda                                                     50.4
# Ukraine                                                   144.0
# United Arab Emirates                                      196.0
# United Kingdom                                            121.0
# United States                                             119.0
# Uruguay                                                   151.0
# Uzbekistan                                                 70.3
# Vanuatu                                                    66.1
# Venezuela                                                  93.4
# Vietnam                                                   129.0
# Yemen                                                      55.8
# Zambia                                                     71.8
# Zimbabwe                                                   80.9
#
# [187 rows x 3 columns]

# %% [markdown]
# # Gráfico 1: Porcentagem de pessoas que utilizam a internet pelo IDH

# %%
Dados.plot.scatter(x="IDH", y="% que usa internet", grid= True, title= "% da população que usa internet pelo IDH (Gráfico 1)");

# %% [markdown]
# ### Conclusões sobre gráfico 1
#
# O gráfico demonstra que mesmo com a revolução técno-informacional, o uso que a população de um país faz da internet continua sendo extremamente dependente do IDH deste país o que comprova que a distribuição de informação ainda é muito pouco democratizada ao redor do mundo.
#
# Esse fenômeno ocorre com a internet por conta do alto custo dos aparelhos necessários para seu acesso. Isso faz com que os países com GDP baixo (e portanto com IDH reduzido) tenham uma menor quantidade de aparelhos que podem acessar a internet (como smartphones, computadores, tablets e televisões).

# %% [markdown]
# # Gráfico 2: Número de celulares para cada 100 pessoas pelo IDH

# %%
Dados.plot.scatter(x="IDH", y="Celulares para cada 100 pessoas", grid= True);

# %% [markdown]
# ### Conclusões sobre o gráfico 2
#
# Esse gráfico, mesmo que ainda tem uma certa tendência, corrobora mais com a hipótese de que a tecnologia vem se democratizando. Isto porque demonstra um gráfico mais heterogêneo, mostrando alguns países com IDHs baixos e que apresentam elevados números de telefones celulares em sua população.
#
# Isso pode ser explicado pelo baixo preço de venda de celulares simples e o amplo acesso à redes telefônicas ao redor do mundo.

# %% [markdown]
# # Gráfico do número de celulares para cada 100 pessoas pela porcentagem de usuários da internet por país

# %%
Dados.plot.scatter(x="% que usa internet", y="Celulares para cada 100 pessoas", grid= True);

# %% [markdown]
# # Comparação com outros anos (2015 - ano base- com 2008 e 2010)

# %%
#=================================== 2010 ===================================
internet_2010= i.iloc[:,50:51]
celular_2010= c.iloc[:,50:51]
idh_2010= h.iloc[:,20:21]


hdi_internet = idh_2010.join(internet_2010, how='inner', rsuffix='_internet', lsuffix='_hdi')
hdi_internet["% que usa internet"]= hdi_internet.pop("2010_internet")
hdi_internet["IDH"]= hdi_internet.pop("2010_hdi")


Dados_2010= hdi_internet.join(celular_2010, how='inner')
Dados_2010["Celulares para cada 100 pessoas"]= Dados_2010.pop(2010)



#=================================== 2008 ===================================
internet_2008= i.iloc[:,48:49]
celular_2008= c.iloc[:,48:49]
idh_2008= h.iloc[:,18:19]


hdi_internet = idh_2008.join(internet_2008, how='inner', rsuffix='_internet', lsuffix='_hdi')
hdi_internet["% que usa internet"]= hdi_internet.pop("2008_internet")
hdi_internet["IDH"]= hdi_internet.pop("2008_hdi")


Dados_2008= hdi_internet.join(celular_2008, how='inner')
Dados_2008["Celulares para cada 100 pessoas"]= Dados_2008.pop(2008)


#=================================== Plotagem dos gráficos (Internet por IDH) ===================================
Dados_2008.plot.scatter(x="IDH", y="% que usa internet", grid= True, title= "2008 - Internet por IDH");
Dados_2010.plot.scatter(x="IDH", y="% que usa internet", grid= True, title= "2010 - Internet por IDH");
Dados.plot.scatter(x="IDH", y="% que usa internet", grid= True, title= "2015 - Internet por IDH");


#=================================== Plotagem dos gráficos (Celulares por IDH) ===================================
Dados_2008.plot.scatter(x="IDH", y="Celulares para cada 100 pessoas", grid= True, title= "2008 - Internet por IDH");
Dados_2010.plot.scatter(x="IDH", y="Celulares para cada 100 pessoas", grid= True, title= "2010 - Internet por IDH");
Dados.plot.scatter(x="IDH", y="Celulares para cada 100 pessoas", grid= True, title= "2015 - Internet por IDH");

# %% [markdown]
# Análisando os doados ao longo do tempo é possível ver uma fortíssima relação de depndência entre IDH e os fatores escolhidos (% da população que utiliza internet e celulares a cada 100 pessoas) no ano de 2005. Porém, no ano de 2010 essa dependência começa a ser menos visível (principalmente no que se trata dos celulares), tendência essa que se mantém também é observável entre os anos de 2010 e 2015. Isso representa que, mesmo em um rítimo lento, as tecnologias estão se democratizando.

# %% [markdown]
# # Conclusões Finais

# %% [markdown]
# #### Correlação 2015

# %%
Dados.corr()
# Out:
#                                  % que usa internet       IDH  \
# % que usa internet                         1.000000  0.921838
# IDH                                        0.921838  1.000000
# Celulares para cada 100 pessoas            0.609088  0.632901
#
#                                  Celulares para cada 100 pessoas
# % que usa internet                                      0.609088
# IDH                                                     0.632901
# Celulares para cada 100 pessoas                         1.000000

# %% [markdown]
# #### Correlação 2010

# %%
Dados_2010.corr()
# Out:
#                                  % que usa internet       IDH  \
# % que usa internet                         1.000000  0.878508
# IDH                                        0.878508  1.000000
# Celulares para cada 100 pessoas            0.651123  0.755623
#
#                                  Celulares para cada 100 pessoas
# % que usa internet                                      0.651123
# IDH                                                     0.755623
# Celulares para cada 100 pessoas                         1.000000

# %% [markdown]
# #### Correlação 2008

# %%
Dados_2008.corr()
# Out:
#                                  % que usa internet       IDH  \
# % que usa internet                         1.000000  0.844736
# IDH                                        0.844736  1.000000
# Celulares para cada 100 pessoas            0.712219  0.809133
#
#                                  Celulares para cada 100 pessoas
# % que usa internet                                      0.712219
# IDH                                                     0.809133
# Celulares para cada 100 pessoas                         1.000000

# %% [markdown]
# #### Matriz de gráficos

# %%
pd.plotting.scatter_matrix(Dados);

# %% [markdown]
# A partir da análise dos dados é possível conluir 3 principais pontos sobre a relação da tecnologia com o nível social de um país nos dias atuais. São eles:
#
#
# #### 1) A população mundial tem mais acesso à telefones celulares do que à internet?
# Isso se da por conta da área de cobertura de celular que é maior que a coberta por internet. Além disso, também é um fator muito relevante o preço baixo dos celulares com relação ao preço do acesso à internet (como comentado anteriormente).
#
#
# #### 2) Democratização da Internet?
# A tecnologia está ficando cada vez mais acessível, o que é possível observar pelos gráfico de 2008, 2010 e 2015. Enquanto no gráfico de 2005 a internet era extremamente restrita para países com baixo IDH, nos gráficos de 2010 e 2015 é possível observar que esse recurso se tornou mais acessível a todos os países (mesmo havendo uma tendência para o maior uso da internet a países com maiores IDHs).
#
#
# #### 3) Democratização dos Celulares?
# Quanto aos telefones celulares, seu acesso em países com IDHs mais baixos é surpreendentemente alto em 2015. Esse uso em países subdesenvolvidos aumentou consideravelmente nos últimos anos, dado que o preço desses dispositivos diminuiu muito.
#
#
# ### 4) Democratização da Tecnologia?
# Ao longo do tempo, foi observado uma diminuição nos índices de correlação entre o IDH e o uso de celulares, comprovando, juntamente com a maior dispersão dos pontos nos gráficos, que o celular vem sim se democratizando.
